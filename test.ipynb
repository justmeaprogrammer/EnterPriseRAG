# %%
    from bs4 import BeautifulSoup

    def parse_html(file_path:str):
        with open(file_path,'r',encoding='utf-8') as f:
            content=f.read()
            
            soup = BeautifulSoup(content,"html.parser")
            
            #Removing junk
            for script in soup(["script", "style", "meta", "noscript"]):
                script.decompose()
                
            ##Extract the text
            text = soup.get_text(separator="\n")
            
            
            ##clean white spaces
            lines = (line.strip() for line in text.splitlines())
            chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
            text_clean = '\n'.join(chunk for chunk in chunks if chunk)
            
            return text_clean
        
        
parse_html("/home/om/projects/EnterpriseRAG/DATA/noisy_data/A Journey in Creating an Operating System Kernel - The 539Kernel Book (Nov 2022).html")
# Out:
# "Noise Dataset Generated Noise Content #2 A Parallel Page Cache explores symbolic execution with emphasis on distributed cache and adaptive synchronization. Experimental observations indicate that multi-core optimization improves system behavior when integrated with compression entropy. Researchers also noted side effects involving neural embedding across heterogeneous runtime environments. A New Algorithm for Data Compression explores adaptive synchronization with emphasis on distributed cache and concurrency control. Experimental observations indicate that vectorized execution improves system behavior when integrated with probabilistic inference. Researchers also noted side effects involving Bayesian convergence across heterogeneous runtime environments. A Method for the Construction of Minimum-Redundancy Codes explores concurrency control with emphasis on parallel computation and compiler abstraction layer. Experimental observations indicate that compression entropy improves system behavior when integrated with transactional throughput. Researchers also noted side effects involving probabilistic inference across heterogeneous runtime environments. A Probabilistic Theory of Deep Learning explores vectorized execution with emphasis on parallel computation and hash collision mitigation. Experimental observations indicate that cache invalidation improves system behavior when integrated with symbolic execution. Researchers also noted side effects involving GPU acceleration across heterogeneous runtime environments. A Malloc Tutorial explores entropy matrix with emphasis on cache invalidation and concurrency control. Experimental observations indicate that parallel computation improves system behavior when integrated with compiler abstraction layer. Researchers also noted side effects involving probabilistic inference across heterogeneous runtime environments. A Look at Intel's Dataplane Development Kit explores symbolic execution with emphasis on transactional throughput and compiler abstraction layer. Experimental observations indicate that dynamic scheduling improves system behavior when integrated with GPU acceleration. Researchers also noted side effects involving Bayesian convergence across heterogeneous runtime environments. A Primer on Memory Consistency and Cache Coherence explores vectorized execution with emphasis on adaptive synchronization and concurrency control. Experimental observations indicate that compression entropy improves system behavior when integrated with symbolic execution. Researchers also noted side effects involving GPU acceleration across heterogeneous runtime environments. A Practical Guide to Support Vector Classification explores probabilistic inference with emphasis on entropy matrix and symbolic execution. Experimental observations indicate that vectorized execution improves system behavior when integrated with adaptive synchronization. Researchers also noted side effects involving cache invalidation across heterogeneous runtime environments. A Look at Intel's Dataplane Development Kit explores vectorized execution with emphasis on parallel computation and transactional throughput. Experimental observations indicate that Bayesian convergence improves system behavior when integrated with entropy matrix. Researchers also noted side effects involving deep learning gradient across heterogeneous runtime environments. A Relational Model of Data for Large Shared Data Banks explores compiler abstraction layer with emphasis on parallel computation and entropy matrix. Experimental observations indicate that memory alignment improves system behavior when integrated with cache invalidation. Researchers also noted side effects involving multi-core optimization across heterogeneous runtime environments. A New Algorithm for Data Compression explores transactional throughput with emphasis on distributed cache and concurrency control. Experimental observations indicate that hash collision mitigation improves sy ...
